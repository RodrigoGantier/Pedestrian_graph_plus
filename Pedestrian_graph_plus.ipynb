# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoGantier/Pedestrian_graph_plus/blob/main/Pedestrian_graph_plus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Install
# !git clone https://github.com/RodrigoGantier/Pedestrian_graph_plus
# !pip install --upgrade --no-cache-dir gdown
# !pip3 install pytorch-lightning
# !pip3 install pickle5
# Out:
# Cloning into 'Pedestrian_graph_plus'...
# remote: Enumerating objects: 248, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 248 (delta 65), reused 95 (delta 45), pack-reused 117
# Receiving objects: 100% (248/248), 26.92 MiB | 10.76 MiB/s, done.
# Resolving deltas: 100% (77/77), done.
# ...
#      |████████████████████████████████| 584 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 408 kB 45.9 MB/s
# ...
#      |████████████████████████████████| 136 kB 46.4 MB/s
# ...
#      |████████████████████████████████| 596 kB 44.2 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 48.4 MB/s
# ...
#      |████████████████████████████████| 144 kB 21.6 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.4 MB/s
# ...
#      |████████████████████████████████| 271 kB 33.8 MB/s
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
#@title Install

# !gdown 1xuJz0pWAevZ-3YKbUttyOp01X_mry-6r -O /content/Pedestrian_graph_plus/data.zip  # data
# !gdown 1s6-xV4j_rzrqIPDtRvY_xFB1lp46drS7 -O /content/Pedestrian_graph_plus/pie.zip  # pie 
# !gdown 17RKd3AxQIFJEdw7CfHrvG1Fg2ZWOcoB3 -O /content/Pedestrian_graph_plus/jaad.zip  # jaad

# !unzip /content/Pedestrian_graph_plus/data.zip -d /content/Pedestrian_graph_plus
# !unzip /content/Pedestrian_graph_plus/pie.zip -d /content/Pedestrian_graph_plus
# !unzip /content/Pedestrian_graph_plus/jaad.zip -d /content/Pedestrian_graph_plus
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set04_video_0002_pid_4_2_1113_fr_14264.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set04_video_0009_pid_4_9_1445_fr_09282.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set04_video_0012_pid_4_12_1557_fr_04034.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set04_video_0012_pid_4_12_1631_fr_20745.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set04_video_0013_pid_4_13_1641_fr_06385.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set04_video_0015_pid_4_15_1683_fr_04455.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set04_video_0016_pid_4_16_1719_fr_11786.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set03_video_0001_pid_3_1_252_fr_09161.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set03_video_0009_pid_3_9_564_fr_00749.pkl
# ...

# %%
import os
os.chdir('/content/Pedestrian_graph_plus')
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT/best.pth
# Out:
# loading test data in memory: 100% 5821/5821 [00:23<00:00, 247.20it/s]
# Testing samples: 100% 5821/5821 [00:42<00:00, 137.40it/s]
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# balance data: False, bh: all, last2: False, Model: jaad-23-IVSFT
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Models statistics
#            accuracy_score  ...  average_precision_score
# PCPA            70.932829  ...                48.247463
# Glob_PCPA       83.490809  ...                54.896822
# FUSSI           60.951727  ...                37.856634
# PedGraph+       86.359732  ...                60.045559
#
# [4 rows x 6 columns]
# No crossing: 89.899
# Crossing: 86.085
# Irrelevant 85.346
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Weather statistics
#               cloudy  ... snow
# PCPA       57.854179  ...  NaN
# Glob_PCPA  70.326409  ...  NaN
# FUSSI      42.399593  ...  NaN
# PedGraph+  71.078431  ...  NaN
#
# [4 rows x 5 columns]
# ...
